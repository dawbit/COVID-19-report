# %%
#install.packages("ggplot2")
library(ggplot2)
#install.packages("dplyr")
library(dplyr)
#install.packages("tidyverse")
library(tidyverse)

multiple_data <- read.csv(file="https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/who_covid_19_sit_rep_time_series.csv", sep = ",")
multiple.df <- data.frame(multiple_data)
multiple.df
#multiple.df[1,2]



#df <- read.csv2("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/who_covid_19_sit_rep_time_series.csv", header= FALSE)
#df
#multiple_data
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# <U+221A> tibble  3.0.1     <U+221A> purrr   0.3.4
# <U+221A> tidyr   1.1.0     <U+221A> stringr 1.4.0
# <U+221A> readr   1.3.1     <U+221A> forcats 0.5.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#     ď.żProvince.States                  Country.Region
# 1   Confirmed                           Globally
# 2   Deaths                              Globally
# 3   Confirmed                           China
# 4   Confirmed                           Outside of China
# 5   Deaths                              China
# 6   Hubei                               China
# ...

# %%
Deaths_raw <- read.csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv")
Deaths_raw
# Out:
#     Province.State                   Country.Region         Lat
# 1                                    Afghanistan             33.0000
# 2                                    Albania                 41.1533
# 3                                    Algeria                 28.0339
# 4                                    Andorra                 42.5063
# 5                                    Angola                 -11.2027
# 6                                    Antigua and Barbuda     17.0608
# 7                                    Argentina              -38.4161
# 8                                    Armenia                 40.0691
# 9   Australian Capital Territory     Australia              -35.4735
# 10  New South Wales                  Australia              -33.8688
# 11  Northern Territory               Australia              -12.4634
# 12  Queensland                       Australia              -28.0167
# 13  South Australia                  Australia              -34.9285
# ...

# %%
Recoveries_raw <- read.csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")
Recoveries_raw
# Out:
#     Province.State                   Country.Region         Lat
# 1                                    Afghanistan             33.0000
# 2                                    Albania                 41.1533
# 3                                    Algeria                 28.0339
# 4                                    Andorra                 42.5063
# 5                                    Angola                 -11.2027
# 6                                    Antigua and Barbuda     17.0608
# 7                                    Argentina              -38.4161
# 8                                    Armenia                 40.0691
# 9   Australian Capital Territory     Australia              -35.4735
# 10  New South Wales                  Australia              -33.8688
# 11  Northern Territory               Australia              -12.4634
# 12  Queensland                       Australia              -28.0167
# 13  South Australia                  Australia              -34.9285
# ...

# %%
pattern <- "..."

#test

v2 <- multiple.df[["Country.Region"]]
#v3 <- filter(multiple.df, grepl("Country.Region", "China"))
#v4 <- filter(grepl("Country.Region", multiple.df))
v5 <- multiple.df[grepl("^[5][0-9][1]$", multiple.df$X1.23.2020), ]
v5 <- multiple.df[grepl("^[5][0-9][1]$", multiple.df$X1.23.2020), ]

#slice(multiple.df, 1:n())
v5

v5[v5$X1.23.2020 == "581"]

bezPierwszych3 = select(multiple.df, contains("2020")) #dookola ale dziala

row1 = bezPierwszych3[1,]

row1

#row1trans <- t(row1)
#row1trans

#colnames(row1trans) <- c("date", "value")
#colnames(row1trans)
#colnames(bezPierwszych3)

#ggplot(row1) + geom_line()

row1[[1]]
colnames(row1)

#ggplot(bezPierwszych3, aes(X4.12.2020,X4.13.2020,"lol")) + geom_line()
#v5
#v5[[117]]
#v4
#v2
# Out:
#    ď.żProvince.States Country.Region WHO.region             X1.21.2020
# 1  Confirmed          Globally                              282
# 3  Confirmed          China          Western Pacific Region 278
# 41                    China          Western Pacific Region 278
#    X1.22.2020 X1.23.2020 X1.24.2020 X1.25.2020 X1.26.2020 X1.27.2020 ...
# 1  314        581        846        1320       2014       2798       ...
# 3  309        571        830        1297       1985       2741       ...
# 41 309        571        830        1297       1985       2741       ...
#    X5.4.2020 X5.5.2020 X5.6.2020 X5.7.2020 X5.8.2020 X5.9.2020 X5.10.2020
# 1  3435894   3517345   3588773   3672238   3759967   3855809   3917366
# 3    84400     84404     84406     84409     84415     84416     84430
# 41   84400     84404     84406     84409     84415     84416     84430
#    X5.11.2020 X5.12.2020 X5.13.2020
# 1  4006257    4088848    4170424
# 3    84450      84451      84458
# ...

# %%
p1 <- ggplot() + geom_line(aes(y = 'test', x = 'test'),
                 data = multiple.data)
p1
# Out:
# Error in fortify(data): nie znaleziono obiektu 'multiple.data'
# Traceback:
#
# 1. geom_line(aes(y = "test", x = "test"), data = multiple.data)
# 2. layer(data = data, mapping = mapping, stat = stat, geom = GeomLine,
#  .     position = position, show.legend = show.legend, inherit.aes = inherit.aes,
#  .     params = list(na.rm = na.rm, orientation = orientation, ...))
# 3. fortify(data)

# %%
xValue <- 1:10
yValue <- cumsum(rnorm(10))
data <- data.frame(xValue,yValue)

# Plot
ggplot(data, aes(x=xValue, y=yValue)) +
  geom_line()
